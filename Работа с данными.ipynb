# %% [markdown]
# # Выработка энергии

# %%
import pandas as pd
import os

file_path = "data/reestr_sertifikatov_100.xlsx"
excel_data = pd.ExcelFile(file_path)

excluded_sheets = ["Раздел 2 Ген. объекты", "Данные о заключенных СДД","АльтЭнерго - Биогазовая станция","АльтЭнерго - Ветряная Электрост","АльтЭнерго - Солнечная Электрос","Байцуры","Лыковская МГЭС","Мечетлиская микро ГЭС","Норд Гидро - Каллиокоски","Норд Гидро - Ляскеля","Норд Гидро - Рюмякоски","Орловский ГОК","ПМТЭЦ Белый ручей","Фаснальская МГЭС","Фотон - Новокарачаевская МГЭС","Фотон-Учкуланская МГЭС","Цимлянская ГЭС","ЧГК- МГЭС Кокадой","Адыгейская ВЭС 1 этап",'Адыгейская ВЭС 2 этап','Адыгейская ВЭС 3 этап','Азовская ВЭС','ВЭС Тюпкильды','Гуковская ВЭС 1 этап','Гуковская ВЭС 2 этап','Гуковская ВЭС 3 этап','Гуковская ВЭС 4 этап','Гуковская ВЭС 5 этап','Каменская ВЭС 1 этап','Каменская ВЭС 2 этап','Кольская ВЭС','Кочубеевская ВЭС ВЭУ5ВЭУ12','Кочубеевская ВЭС ВЭУ13ВЭУ20','Кочубеевская ВЭС ВЭУ21ВЭУ28','Кочубеевская ВЭС ВЭУ29ВЭУ36','Кочубеевская ВЭС ВЭУ69ВЭУ76','Кочубеевская ВЭС ВЭУ77ВЭУ84','Кочубеевская ВЭС 1-4','Кочубеевская ВЭС 37-44','Кочубеевская ВЭС 45-52','Кочубеевская ВЭС 53-60','Кочубеевская ВЭС 61-68','Марченковская ВЭСВЭУ25-ВЭУ32','Сулинская ВЭС 1 этап','Сулинская ВЭС 2 этап','Фортум ВЭС Ульяновска']

target_sheets = [s for s in excel_data.sheet_names if s not in excluded_sheets]

output_dir = "output/выработка_по_листам"
os.makedirs(output_dir, exist_ok=True)

# %%
# Поиск колонок по маске
def find_column_precise(cols, keyword):
    for col in cols:
        if keyword.lower() in str(col).lower():
            return col
    return None

# %%
import os
import pandas as pd
import numpy as np

MIN_ROWS = 24  # минимальное число строк для сохранения

for sheet in target_sheets:
    try:
        # 1) Чтение листа из Excel
        df = excel_data.parse(sheet, header=3)
        df.columns = df.columns.str.strip()

        # 2) Нахождение нужных колонок
        col_op         = find_column_precise(df.columns, "вид операц")
        col_period     = find_column_precise(df.columns, "расчетный период")
        col_issued     = find_column_precise(df.columns, "выдан сертификат")
        col_unredeemed = find_column_precise(df.columns, "не погашен")
        col_number     = find_column_precise(df.columns, "номер сертификата")

        if not all([col_op, col_period, col_issued, col_unredeemed, col_number]):
            raise ValueError("Не найдены все нужные колонки")

        # 3) Переименование
        df = df.rename(columns={
            col_op:         'Операция',
            col_period:     'Период',
            col_issued:     'Выдано, кВт*ч',
            col_unredeemed: 'Не погашено, кВт*ч',
            col_number:     'Номер'
        })

        # 4) Предобработка
        df['Номер']    = df['Номер'].ffill()
        df['Операция'] = df['Операция'].astype(str).str.lower()

        # 5) Разделение на выпуски и погашения/изменения
        df_vypusk = df[df['Операция'].str.contains('выпуск', na=False)]
        df_izm    = df[df['Операция'].str.contains('изменение', na=False)]
        df_pogash = df[df['Операция'].str.contains('погашение', na=False)]

        df_izm_or_pogash = pd.concat([df_izm, df_pogash]) \
                              .sort_values(['Номер','Операция']) \
                              .drop_duplicates(subset='Номер', keep='first')

        # 6) Слияние по номеру сертификата
        merged = pd.merge(
            df_vypusk[['Номер','Период','Выдано, кВт*ч']],
            df_izm_or_pogash[['Номер','Не погашено, кВт*ч']],
            on='Номер',
            how='left'
        )

        # 7) Конвертация в числа
        merged['Выдано, кВт*ч']       = pd.to_numeric(merged['Выдано, кВт*ч'],    errors='coerce')
        merged['Не погашено, кВт*ч']  = pd.to_numeric(merged['Не погашено, кВт*ч'],errors='coerce')

        # 8) Вычисление выработки и безопасное приведение к nullable Int
        diff = (merged['Выдано, кВт*ч'] - merged['Не погашено, кВт*ч']).round()
        merged['Выработанная энергия, кВт*ч'] = diff.astype('Int64')

        # 9) Финальная таблица
        final_table = (
            merged[['Период','Выработанная энергия, кВт*ч']]
              .dropna(subset=['Выработанная энергия, кВт*ч'])
        )

        # 10) Преобразование периода в Period[M]
        final_table['Период'] = (
            final_table['Период']
              .astype(str)
              .str.extract(r'(\d{2}\.\d{4})')[0]
        )
        final_table['Период'] = pd.to_datetime(
            final_table['Период'], format="%m.%Y", errors='coerce'
        ).dt.to_period("M")

        final_table = final_table.dropna().drop_duplicates()

        # 11) Формирование имени и удаление лидирующих/концевых пробелов
        safe_name = "".join(
            c for c in sheet
            if c.isalnum() or c in (' ','-','_')
        )
        safe_name = safe_name.strip()  # убираем ведущие и конечные пробелы
        csv_path  = os.path.join(output_dir, f"{safe_name}.csv")

        # 12) Сохранение
        final_table.to_csv(csv_path, index=False, encoding='utf-8')

        # 13) Удаление, если строк меньше MIN_ROWS
        row_count = len(final_table)
        if row_count < MIN_ROWS:
            os.remove(csv_path)
            print(f"Файл {csv_path} удалён — всего {row_count} строк (<{MIN_ROWS}).")
        else:
            print(f"Файл {csv_path} сохранён — {row_count} строк.")

    except Exception as e:
        print(f"[{sheet}] Ошибка: {e}")
# Out:
# Файл output/выработка_по_листам/ЭкоСельЭнерго-1.csv сохранён — 65 строк.
# Файл output/выработка_по_листам/ЭкоСельЭнерго-2.csv сохранён — 35 строк.
# Файл output/выработка_по_листам/ВИРЕО ЭНЕРДЖИ - Новый Свет-Эко.csv сохранён — 54 строк.
# Файл output/выработка_по_листам/АвеларСолар - Кош-Агачская СЭС.csv сохранён — 105 строк.
# Файл output/выработка_по_листам/АвеларСолар - Переволоцкая СЭС.csv сохранён — 98 строк.
# Файл output/выработка_по_листам/Бурибаевская СЭС 2.csv сохранён — 82 строк.
# Файл output/выработка_по_листам/Бурибаевская СЭС.csv сохранён — 94 строк.
# Файл output/выработка_по_листам/АвеларСолар -БугульчанскаяСЭС1.csv сохранён — 52 строк.
# Файл output/выработка_по_листам/АвеларСолар -БугульчанскаяСЭС2.csv сохранён — 43 строк.
# Файл output/выработка_по_листам/АвеларСолар -БугульчанскаяСЭС3.csv сохранён — 43 строк.
# Файл output/выработка_по_листам/АвеларСолар - Кош-Агачская 2.csv сохранён — 93 строк.
# Файл output/выработка_по_листам/Грачевская СЭС.csv сохранён — 41 строк.
# Файл output/выработка_по_листам/АвеларСолар - Усть-Канская СЭС.csv сохранён — 85 строк.
# Файл output/выработка_по_листам/АвеларСолар - Соль-Илецкая.csv сохранён — 80 строк.
# Файл output/выработка_по_листам/Плешановская СЭС.csv сохранён — 41 строк.
# Файл output/выработка_по_листам/АвеларСолар - Майминская 1.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/АвеларСолар - Майминская 2.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/АвеларСолар - Онгудайская.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/АвеларСолар - Пугачевская.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/АвеларСолар - Орловгайская 1.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/АвеларСолар - Бичурская.csv сохранён — 73 строк.
# Файл output/выработка_по_листам/Лукойл - Волгоградская СЭС.csv сохранён — 58 строк.
# Файл output/выработка_по_листам/АвеларСолар - Исянгуловская.csv сохранён — 72 строк.
# Файл output/выработка_по_листам/Абаканская СЭС.csv сохранён — 56 строк.
# Файл output/выработка_по_листам/Солнечный ве - Державинская СЭС.csv сохранён — 78 строк.
# Файл output/выработка_по_листам/СЭС им АА Влазнева.csv сохранён — 94 строк.
# Файл output/выработка_по_листам/Солнеч ветер Оренбургская СЭС-5.csv сохранён — 77 строк.
# Файл output/выработка_по_листам/Сан проджект - Заводская СЭС.csv сохранён — 69 строк.
# Файл output/выработка_по_листам/СЭС Нива.csv сохранён — 68 строк.
# Файл output/выработка_по_листам/СЭС Промстройматериалы.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/СЭС Володаровка.csv сохранён — 67 строк.
# Файл output/выработка_по_листам/СЭС Енотаевка.csv сохранён — 63 строк.
# Файл output/выработка_по_листам/Новоузенская СЭС.csv сохранён — 62 строк.
# Файл output/выработка_по_листам/Ветропарк ФРВ 1.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Ветропарк ФРВ 2.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Фунтовская СЭС 1.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Фунтовская СЭС 2.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Фунтовская СЭС 3.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Фунтовская СЭС 4.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Оренбургская СЭС-1.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Оренбургская СЭС-3.csv сохранён — 61 строк.
# Файл output/выработка_по_листам/Самарская СЭС-2 1 очередь.csv сохранён — 53 строк.
# Файл output/выработка_по_листам/Орловгайская СЭС 2 очередь.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Чкаловская СЭС.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Ахтубинская СЭС 1 очередь.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Ахтубинская СЭС 2 очередь.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Ахтубинская СЭС 3 очередь.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Ахтубинская СЭС 4 очередь.csv сохранён — 59 строк.
# Файл output/выработка_по_листам/Самарская СЭС  2 2 очередь.csv сохранён — 52 строк.
# Файл output/выработка_по_листам/Майминская СЭС-3.csv сохранён — 58 строк.
# Файл output/выработка_по_листам/Ининская СЭС.csv сохранён — 58 строк.
# Файл output/выработка_по_листам/СЭС Элиста Северная.csv сохранён — 58 строк.
# Файл output/выработка_по_листам/Самарская СЭС-2 3 очередь.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС Михайловская.csv сохранён — 57 строк.
# Файл output/выработка_по_листам/Григорьевская солнечная электр.csv сохранён — 56 строк.
# Файл output/выработка_по_листам/Елшанская СЭС 1 очередь.csv сохранён — 55 строк.
# Файл output/выработка_по_листам/Елшанская СЭС 2 очередь.csv сохранён — 55 строк.
# Файл output/выработка_по_листам/СЭС Ташла.csv сохранён — 46 строк.
# Файл output/выработка_по_листам/СЭС Калиновка.csv сохранён — 46 строк.
# Файл output/выработка_по_листам/СЭС Грачевка.csv сохранён — 45 строк.
# Файл output/выработка_по_листам/СЭС Красная.csv сохранён — 43 строк.
# Файл output/выработка_по_листам/Ининская 2 очередь.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Усть-Коксинская СЭС 2 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Усть-Коксинская СЭС 1 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Усть-Коксинская СЭС 4 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Усть-Коксинская СЭС 3 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Малодербетовская СЭС 1 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС Яшкульская 585 МВт 2 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС Яшкульская 585 МВт 1 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Домбаровская СЭС 25 МВт.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Лиманская СЭС 30 МВт 1 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Лиманская СЭС 30 МВт 2 этап.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Хоринская СЭС 15 МВт.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Балей СЭС.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС БВС.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС Кабанская.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/СЭС Тарбагатай.csv сохранён — 50 строк.
# Файл output/выработка_по_листам/Чемальская СЭС 10 МВт.csv сохранён — 49 строк.
# Файл output/выработка_по_листам/Старомарьевская СЭС 3.csv сохранён — 41 строк.
# Файл output/выработка_по_листам/Октябрьская СЭС.csv сохранён — 41 строк.
# Файл output/выработка_по_листам/Старомарьевская 5 очередь.csv сохранён — 40 строк.
# Файл output/выработка_по_листам/Песчаная СЭС.csv сохранён — 41 строк.
# Файл output/выработка_по_листам/Оренбургская СЭС-4.csv сохранён — 47 строк.
# Файл output/выработка_по_листам/Адыгейская ВЭС 1 этап.csv сохранён — 25 строк.
# Файл output/выработка_по_листам/Адыгейская ВЭС 2 этап.csv сохранён — 24 строк.
# Файл output/выработка_по_листам/Волгоградская СЭС 1 2 очередь.csv сохранён — 39 строк.
# Файл output/выработка_по_листам/Старомарьевская СЭС 6 очередь.csv сохранён — 38 строк.
# Файл output/выработка_по_листам/Светлинская СЭС ПК-1.csv сохранён — 46 строк.
# Файл output/выработка_по_листам/Адыгейская ВЭС 3 этап.csv удалён — всего 23 строк (<24).
# Файл output/выработка_по_листам/Верхнебалкарская малая ГЭС.csv удалён — всего 1 строк (<24).
# Файл output/выработка_по_листам/Верхняя Бурзянская СЭС.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/Нижняя Бурзянская СЭС.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС Луч 1.csv сохранён — 34 строк.
# Файл output/выработка_по_листам/Калмыкская СЭС-1.csv сохранён — 33 строк.
# Файл output/выработка_по_листам/Малодербетовская СЭС 60 МВт-2.csv сохранён — 38 строк.
# Файл output/выработка_по_листам/Яшкульская СЭС 585 МВт-3.csv сохранён — 38 строк.
# Файл output/выработка_по_листам/Дергачевская СЭС 60 МВт-1.csv сохранён — 38 строк.
# Файл output/выработка_по_листам/СЭС Астерион.csv сохранён — 31 строк.
# Файл output/выработка_по_листам/СЭС Адыгейская.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/Торейская СЭС 45 МВт 2 этап.csv сохранён — 37 строк.
# Файл output/выработка_по_листам/Торейская СЭС 45 МВт 1 этап.csv сохранён — 37 строк.
# Файл output/выработка_по_листам/Нововаршавская СЭС 1 этап.csv сохранён — 37 строк.
# Файл output/выработка_по_листам/Нововаршавская СЭС 2 этап.csv сохранён — 37 строк.
# Файл output/выработка_по_листам/СЭС Медведица.csv сохранён — 29 строк.
# Файл output/выработка_по_листам/СЭС Сигма Дракона.csv сохранён — 28 строк.
# Файл output/выработка_по_листам/СЭС Шовгеновская.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/Наурская СЭС.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/Русско-Полянская СЭС 30 МВт-2.csv сохранён — 26 строк.
# Файл output/выработка_по_листам/Русско-Полянская СЭС 30 МВт-1.csv сохранён — 26 строк.
# Файл output/выработка_по_листам/Новопереволоцкая СЭС 15 МВт.csv сохранён — 26 строк.
# Файл output/выработка_по_листам/Читинская СЭС 35 МВт.csv сохранён — 26 строк.
# Файл output/выработка_по_листам/Светлинская СЭС ПК-2 25 МВт.csv сохранён — 25 строк.
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ29ВЭУ36.csv удалён — всего 14 строк (<24).
# Файл output/выработка_по_листам/Нефтезаводская СЭС 20 МВт.csv сохранён — 24 строк.
# Файл output/выработка_по_листам/Читинская СЭС 35 МВт - 2 этап.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Дергачевская СЭС 60 МВт 3 этап.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Дергачевская СЭС 60 МВт 2 этап.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Южно-Сухокумская СЭС 15 МВт.csv удалён — всего 20 строк (<24).
# Файл output/выработка_по_листам/Черновская СЭС 35 МВт 1 этап.csv удалён — всего 19 строк (<24).
# Файл output/выработка_по_листам/Черновская СЭС 35 МВт 2 этап.csv удалён — всего 19 строк (<24).
# Файл output/выработка_по_листам/СЭС-10Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-11Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-12Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-13Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-14Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-15Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-16Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-17Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/СЭС-18Кр.csv удалён — всего 0 строк (<24).
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ5ВЭУ12.csv удалён — всего 13 строк (<24).
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ13ВЭУ20.csv удалён — всего 13 строк (<24).
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ21ВЭУ28.csv удалён — всего 13 строк (<24).
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ69ВЭУ76.csv удалён — всего 13 строк (<24).
# Файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ77ВЭУ84.csv удалён — всего 13 строк (<24).
# Файл output/выработка_по_листам/Марченковская ВЭСВЭУ25-ВЭУ32.csv удалён — всего 13 строк (<24).

# %%
import os
import pandas as pd
import numpy as np
import requests
import calendar
from datetime import datetime as dt

# Загрузка координат объектов
coords_df = pd.read_csv(
    'data/Объекты_с_координатами.csv',
    encoding='windows-1251',
    sep=';'
)

# Функция для запроса исторических метео-данных
def fetch_weather(lat, lon, start_date, end_date):
    url = (
        f'https://archive-api.open-meteo.com/v1/archive'
        f'?latitude={lat}&longitude={lon}'
        f'&start_date={start_date}&end_date={end_date}'
        f'&daily=temperature_2m_max,temperature_2m_min,'
        f'precipitation_sum,windspeed_10m_max,'
        f'cloudcover_mean,pressure_msl_mean,dewpoint_2m_mean'
        f'&timezone=auto'
    )
    resp = requests.get(url)
    resp.raise_for_status()
    return resp.json().get('daily', {})

# Дневная инсоляция (МДж/м²) по широте и дню года
def solar_insolation(lat_deg, day_of_year):
    phi = np.deg2rad(lat_deg)
    delta = np.deg2rad(23.45 * np.sin(2 * np.pi * (284 + day_of_year) / 365))
    omega_s = np.arccos(-np.tan(phi) * np.tan(delta))
    dr = 1 + 0.033 * np.cos(2 * np.pi * day_of_year / 365)
    I_sc = 1367  # Вт/м²
    H0 = (24 * 3600 / np.pi) * I_sc * dr * (
        omega_s * np.sin(phi) * np.sin(delta) +
        np.cos(phi) * np.cos(delta) * np.sin(omega_s)
    )
    return H0 / 1e6  # в МДж/м²

# Суммарная инсоляция за календарный месяц
def monthly_insolation(lat, year, month):
    days = calendar.monthrange(year, month)[1]
    total = 0.0
    for d in range(1, days + 1):
        doy = dt(year, month, d).timetuple().tm_yday
        total += solar_insolation(lat, doy)
    return total

# Список столбцов, которые должны присутствовать в таблице
required_cols = [
    'Температура, °C',
    'Скорость ветра, м/с',
    'Осадки, мм',
    'Облачность, %',
    'Давление, гПа',
    'Точка росы, °C',
    'Инсоляция, МДж/м²'
]

# Обрабатываем каждый объект
for _, coord in coords_df.iterrows():
    obj = coord['Объект']
    lat, lon = coord['Широта'], coord['Долгота']
    path = f"output/выработка_по_листам/{obj}.csv"

    # Пропускаем, если CSV-файла нет
    if not os.path.exists(path):
        print(f"Пропущен {obj}: файл {path} не найден.")
        continue

    df = pd.read_csv(path)

    # 1) Добавляем недостающие колонки
    for c in required_cols:
        if c not in df.columns:
            df[c] = np.nan

    # 2) Находим периоды, где хоть один столбец из required_cols пуст
    mask = df[required_cols].isnull().any(axis=1)
    periods = df.loc[mask, 'Период'].unique()

    # 3) Для каждого такого периода запрашиваем и считаем данные
    for period in periods:
        year, month = map(int, period.split('-'))
        start = f"{year:04d}-{month:02d}-01"
        end_day = calendar.monthrange(year, month)[1]
        end   = f"{year:04d}-{month:02d}-{end_day:02d}"

        daily = fetch_weather(lat, lon, start, end)

        # средние метео-параметры за месяц
        t_max = np.array(daily.get('temperature_2m_max', []))
        t_min = np.array(daily.get('temperature_2m_min', []))
        wind  = np.array(daily.get('windspeed_10m_max', []))
        prec  = np.array(daily.get('precipitation_sum', []))
        cloud = np.array(daily.get('cloudcover_mean', []))
        press = np.array(daily.get('pressure_msl_mean', []))
        dew   = np.array(daily.get('dewpoint_2m_mean', []))

        ins = monthly_insolation(lat, year, month)

        # записываем в DataFrame
        idx = df[df['Период'] == period].index
        df.loc[idx, 'Температура, °C']     = float(((t_max + t_min) / 2).mean())
        df.loc[idx, 'Скорость ветра, м/с'] = float(wind.mean())
        df.loc[idx, 'Осадки, мм']          = float(prec.mean())
        df.loc[idx, 'Облачность, %']       = float(cloud.mean())
        df.loc[idx, 'Давление, гПа']       = float(press.mean())
        df.loc[idx, 'Точка росы, °C']      = float(dew.mean())
        df.loc[idx, 'Инсоляция, МДж/м²']    = ins

    # 4) Сохраняем только если были пропуски
    if len(periods) > 0:
        df.to_csv(path, index=False, encoding='utf-8')
        print(f"Заполнено и сохранено для {obj}: {len(periods)} период(а/ов)")
    else:
        print(f"Нет пропусков для {obj}, пропущено.")
# Out:
# Нет пропусков для АвеларСолар - Кош-Агачская СЭС, пропущено.
# Нет пропусков для СЭС им АА Влазнева, пропущено.
# Нет пропусков для СЭС Луч 1, пропущено.
# Нет пропусков для СЭС БВС, пропущено.
# Нет пропусков для СЭС Нива, пропущено.
# Нет пропусков для СЭС Сигма Дракона, пропущено.
# Нет пропусков для СЭС Ташла, пропущено.
# Нет пропусков для СЭС Элиста Северная, пропущено.
# Нет пропусков для СЭС Красная, пропущено.
# Нет пропусков для Сан проджект - Заводская СЭС, пропущено.
# Нет пропусков для СЭС Астерион, пропущено.
# Нет пропусков для СЭС Грачевка, пропущено.
# Пропущен ВЭС Тюпкильды: файл output/выработка_по_листам/ВЭС Тюпкильды.csv не найден.
# Нет пропусков для СЭС Енотаевка, пропущено.
# Нет пропусков для СЭС Кабанская, пропущено.
# Нет пропусков для СЭС Калиновка, пропущено.
# Нет пропусков для СЭС Медведица, пропущено.
# Нет пропусков для СЭС Яшкульская 585 МВт 1 этап, пропущено.
# Нет пропусков для СЭС Яшкульская 585 МВт 2 этап, пропущено.
# Пропущен СЭС Адыгейская: файл output/выработка_по_листам/СЭС Адыгейская.csv не найден.
# Нет пропусков для СЭС Тарбагатай, пропущено.
# Нет пропусков для СЭС Володаровка, пропущено.
# Нет пропусков для СЭС Михайловская, пропущено.
# Пропущен СЭС Шовгеновская: файл output/выработка_по_листам/СЭС Шовгеновская.csv не найден.
# Нет пропусков для СЭС Промстройматериалы, пропущено.
# Пропущен СЭС-10Кр: файл output/выработка_по_листам/СЭС-10Кр.csv не найден.
# Пропущен СЭС-11Кр: файл output/выработка_по_листам/СЭС-11Кр.csv не найден.
# Пропущен СЭС-12Кр: файл output/выработка_по_листам/СЭС-12Кр.csv не найден.
# Пропущен СЭС-13Кр: файл output/выработка_по_листам/СЭС-13Кр.csv не найден.
# Пропущен СЭС-14Кр: файл output/выработка_по_листам/СЭС-14Кр.csv не найден.
# Пропущен СЭС-15Кр: файл output/выработка_по_листам/СЭС-15Кр.csv не найден.
# Пропущен СЭС-16Кр: файл output/выработка_по_листам/СЭС-16Кр.csv не найден.
# Пропущен СЭС-17Кр: файл output/выработка_по_листам/СЭС-17Кр.csv не найден.
# Пропущен СЭС-18Кр: файл output/выработка_по_листам/СЭС-18Кр.csv не найден.
# Нет пропусков для Усть-Коксинская СЭС 1 этап, пропущено.
# Нет пропусков для Усть-Коксинская СЭС 2 этап, пропущено.
# Нет пропусков для Усть-Коксинская СЭС 3 этап, пропущено.
# Нет пропусков для Усть-Коксинская СЭС 4 этап, пропущено.
# Пропущен Южно-Сухокумская СЭС 15 МВт: файл output/выработка_по_листам/Южно-Сухокумская СЭС 15 МВт.csv не найден.
# Нет пропусков для Балей СЭС, пропущено.
# Нет пропусков для Лукойл - Волгоградская СЭС, пропущено.
# Пропущен Фортум ВЭС Ульяновска: файл output/выработка_по_листам/Фортум ВЭС Ульяновска.csv не найден.
# Нет пропусков для Солнеч ветер Оренбургская СЭС-5, пропущено.
# Пропущен Нижняя Бурзянская СЭС: файл output/выработка_по_листам/Нижняя Бурзянская СЭС.csv не найден.
# Нет пропусков для Русско-Полянская СЭС 30 МВт-1, пропущено.
# Нет пропусков для Русско-Полянская СЭС 30 МВт-2, пропущено.
# Пропущен Верхняя Бурзянская СЭС: файл output/выработка_по_листам/Верхняя Бурзянская СЭС.csv не найден.
# Нет пропусков для Ининская 2 очередь, пропущено.
# Пропущен Азовская ВЭС: файл output/выработка_по_листам/Азовская ВЭС.csv не найден.
# Нет пропусков для Ининская СЭС, пропущено.
# Пропущен Кольская ВЭС: файл output/выработка_по_листам/Кольская ВЭС.csv не найден.
# Пропущен Наурская СЭС: файл output/выработка_по_листам/Наурская СЭС.csv не найден.
# Нет пропусков для Песчаная СЭС, пропущено.
# Нет пропусков для Солнечный ве - Державинская СЭС, пропущено.
# Нет пропусков для Самарская СЭС  2 2 очередь, пропущено.
# Пропущен Гуковская ВЭС 1 этап: файл output/выработка_по_листам/Гуковская ВЭС 1 этап.csv не найден.
# Пропущен Каменская ВЭС 1 этап: файл output/выработка_по_листам/Каменская ВЭС 1 этап.csv не найден.
# Пропущен Сулинская ВЭС 1 этап: файл output/выработка_по_листам/Сулинская ВЭС 1 этап.csv не найден.
# Нет пропусков для Елшанская СЭС 1 очередь, пропущено.
# Пропущен Ветропарк ФРВ 1: файл output/выработка_по_листам/Ветропарк ФРВ 1.csv не найден.
# Нет пропусков для Хоринская СЭС 15 МВт, пропущено.
# Пропущен Гуковская ВЭС 2 этап: файл output/выработка_по_листам/Гуковская ВЭС 2 этап.csv не найден.
# Пропущен Каменская ВЭС 2 этап: файл output/выработка_по_листам/Каменская ВЭС 2 этап.csv не найден.
# Пропущен Сулинская ВЭС 2 этап: файл output/выработка_по_листам/Сулинская ВЭС 2 этап.csv не найден.
# Нет пропусков для Елшанская СЭС 2 очередь, пропущено.
# Пропущен Ветропарк ФРВ 2: файл output/выработка_по_листам/Ветропарк ФРВ 2.csv не найден.
# Пропущен Гуковская ВЭС 3 этап: файл output/выработка_по_листам/Гуковская ВЭС 3 этап.csv не найден.
# Нет пропусков для Лиманская СЭС 30 МВт 1 этап, пропущено.
# Нет пропусков для Лиманская СЭС 30 МВт 2 этап, пропущено.
# Пропущен Читинская СЭС 35 МВт - 2 этап: файл output/выработка_по_листам/Читинская СЭС 35 МВт - 2 этап.csv не найден.
# Нет пропусков для Читинская СЭС 35 МВт, пропущено.
# Пропущен Гуковская ВЭС 4 этап: файл output/выработка_по_листам/Гуковская ВЭС 4 этап.csv не найден.
# Нет пропусков для Торейская СЭС 45 МВт 1 этап, пропущено.
# Нет пропусков для Торейская СЭС 45 МВт 2 этап, пропущено.
# Пропущен Гуковская ВЭС 5 этап: файл output/выработка_по_листам/Гуковская ВЭС 5 этап.csv не найден.
# Нет пропусков для Самарская СЭС-2 1 очередь, пропущено.
# Нет пропусков для Самарская СЭС-2 3 очередь, пропущено.
# Нет пропусков для Адыгейская ВЭС 1 этап, пропущено.
# Нет пропусков для Фунтовская СЭС 1, пропущено.
# Нет пропусков для Чемальская СЭС 10 МВт, пропущено.
# Нет пропусков для Адыгейская ВЭС 2 этап, пропущено.
# Нет пропусков для Фунтовская СЭС 2, пропущено.
# Пропущен Адыгейская ВЭС 3 этап: файл output/выработка_по_листам/Адыгейская ВЭС 3 этап.csv не найден.
# Нет пропусков для Фунтовская СЭС 3, пропущено.
# Пропущен Черновская СЭС 35 МВт 1 этап: файл output/выработка_по_листам/Черновская СЭС 35 МВт 1 этап.csv не найден.
# Пропущен Черновская СЭС 35 МВт 2 этап: файл output/выработка_по_листам/Черновская СЭС 35 МВт 2 этап.csv не найден.
# Нет пропусков для Фунтовская СЭС 4, пропущено.
# Нет пропусков для Яшкульская СЭС 585 МВт-3, пропущено.
# Нет пропусков для Калмыкская СЭС-1, пропущено.
# Нет пропусков для Майминская СЭС-3, пропущено.
# Нет пропусков для Абаканская СЭС, пропущено.
# Нет пропусков для Грачевская СЭС, пропущено.
# Нет пропусков для Чкаловская СЭС, пропущено.
# Нет пропусков для АвеларСолар - Кош-Агачская 2, пропущено.
# Нет пропусков для АвеларСолар - Усть-Канская СЭС, пропущено.
# Нет пропусков для АвеларСолар - Соль-Илецкая, пропущено.
# Нет пропусков для АвеларСолар - Бичурская, пропущено.
# Нет пропусков для АвеларСолар - Майминская 1, пропущено.
# Нет пропусков для АвеларСолар - Майминская 2, пропущено.
# Нет пропусков для АвеларСолар - Онгудайская, пропущено.
# Нет пропусков для АвеларСолар - Пугачевская, пропущено.
# Нет пропусков для АвеларСолар - Орловгайская 1, пропущено.
# Нет пропусков для АвеларСолар - Переволоцкая СЭС, пропущено.
# Нет пропусков для АвеларСолар - Исянгуловская, пропущено.
# Нет пропусков для АвеларСолар -БугульчанскаяСЭС1, пропущено.
# Заполнено и сохранено для АвеларСолар -БугульчанскаяСЭС2: 43 период(а/ов)
# Заполнено и сохранено для АвеларСолар -БугульчанскаяСЭС3: 43 период(а/ов)
# Заполнено и сохранено для Ахтубинская СЭС 1 очередь: 59 период(а/ов)
# Заполнено и сохранено для Ахтубинская СЭС 2 очередь: 59 период(а/ов)
# Заполнено и сохранено для Ахтубинская СЭС 3 очередь: 59 период(а/ов)
# Заполнено и сохранено для Ахтубинская СЭС 4 очередь: 59 период(а/ов)
# Заполнено и сохранено для Светлинская СЭС ПК-1: 46 период(а/ов)
# Заполнено и сохранено для Светлинская СЭС ПК-2 25 МВт: 25 период(а/ов)
# Заполнено и сохранено для Октябрьская СЭС: 41 период(а/ов)
# Пропущен Кочубеевская ВЭС 1-4: файл output/выработка_по_листам/Кочубеевская ВЭС 1-4.csv не найден.
# Заполнено и сохранено для Орловгайская СЭС 2 очередь: 59 период(а/ов)
# Заполнено и сохранено для Бурибаевская СЭС 2: 82 период(а/ов)
# Заполнено и сохранено для Домбаровская СЭС 25 МВт: 50 период(а/ов)
# Пропущен Кочубеевская ВЭС 37-44: файл output/выработка_по_листам/Кочубеевская ВЭС 37-44.csv не найден.
# Пропущен Кочубеевская ВЭС 45-52: файл output/выработка_по_листам/Кочубеевская ВЭС 45-52.csv не найден.
# Пропущен Кочубеевская ВЭС 53-60: файл output/выработка_по_листам/Кочубеевская ВЭС 53-60.csv не найден.
# Пропущен Дергачевская СЭС 60 МВт 2 этап: файл output/выработка_по_листам/Дергачевская СЭС 60 МВт 2 этап.csv не найден.
# Пропущен Дергачевская СЭС 60 МВт 3 этап: файл output/выработка_по_листам/Дергачевская СЭС 60 МВт 3 этап.csv не найден.
# Заполнено и сохранено для Дергачевская СЭС 60 МВт-1: 38 период(а/ов)
# Пропущен Кочубеевская ВЭС 61-68: файл output/выработка_по_листам/Кочубеевская ВЭС 61-68.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ13ВЭУ20: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ13ВЭУ20.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ21ВЭУ28: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ21ВЭУ28.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ29ВЭУ36: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ29ВЭУ36.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ5ВЭУ12: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ5ВЭУ12.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ69ВЭУ76: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ69ВЭУ76.csv не найден.
# Пропущен Кочубеевская ВЭС ВЭУ77ВЭУ84: файл output/выработка_по_листам/Кочубеевская ВЭС ВЭУ77ВЭУ84.csv не найден.
# Заполнено и сохранено для Оренбургская СЭС-1: 61 период(а/ов)
# Заполнено и сохранено для Оренбургская СЭС-3: 61 период(а/ов)
# Заполнено и сохранено для Оренбургская СЭС-4: 47 период(а/ов)
# Заполнено и сохранено для Бурибаевская СЭС: 94 период(а/ов)
# Заполнено и сохранено для Новоузенская СЭС: 62 период(а/ов)
# Заполнено и сохранено для Плешановская СЭС: 41 период(а/ов)
# Заполнено и сохранено для Волгоградская СЭС 1 2 очередь: 39 период(а/ов)
# Пропущен Марченковская ВЭСВЭУ25-ВЭУ32: файл output/выработка_по_листам/Марченковская ВЭСВЭУ25-ВЭУ32.csv не найден.
# Заполнено и сохранено для Григорьевская солнечная электр: 56 период(а/ов)
# Заполнено и сохранено для ЭкоСельЭнерго-1: 65 период(а/ов)
# Заполнено и сохранено для ЭкоСельЭнерго-2: 35 период(а/ов)
# Заполнено и сохранено для Нововаршавская СЭС 1 этап: 37 период(а/ов)
# Заполнено и сохранено для Нововаршавская СЭС 2 этап: 37 период(а/ов)
# Заполнено и сохранено для Нефтезаводская СЭС 20 МВт: 24 период(а/ов)
# Заполнено и сохранено для Старомарьевская 5 очередь: 40 период(а/ов)
# Заполнено и сохранено для Старомарьевская СЭС 3: 41 период(а/ов)
# Заполнено и сохранено для Старомарьевская СЭС 6 очередь: 38 период(а/ов)
# Заполнено и сохранено для Малодербетовская СЭС 1 этап: 50 период(а/ов)
# Заполнено и сохранено для Новопереволоцкая СЭС 15 МВт: 26 период(а/ов)
# Заполнено и сохранено для Малодербетовская СЭС 60 МВт-2: 38 период(а/ов)

# %%
# Путь к директории с таблицами
folder_path = 'output/выработка_по_листам'

weather_columns = [
    'Температура, °C',
    'Скорость ветра, м/с',
    'Осадки, мм',
    'Облачность, %',
    'Давление, гПа',
    'Точка росы, °C',
    'Инсоляция, МДж/м²'
]

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        filepath = os.path.join(folder_path, filename)
        df = pd.read_csv(filepath)

        # Проверяем, что все нужные столбцы есть
        present_cols = [col for col in weather_columns if col in df.columns]
        if present_cols:
            df[present_cols] = df[present_cols].round(2)

            # Новое имя файла с расширением .xlsx
            excel_path = filepath.replace('.csv', '.xlsx')
            excel_path = excel_path.replace('выработка_по_листам', 'готовая_выработка_excel')

            df.to_excel(excel_path, index=False)
            print(f"Округлено и сохранено в Excel: {excel_path}")
        else:
            print(f"Пропущен (нет погодных данных): {filename}")
# Out:
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Балей СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Дергачевская СЭС 60 МВт-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Бурибаевская СЭС 2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Елшанская СЭС 1 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Самарская СЭС-2 3 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Оренбургская СЭС-4.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Абаканская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Медведица.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Солнечный ве - Державинская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Пугачевская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Чкаловская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Оренбургская СЭС-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Переволоцкая СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Оренбургская СЭС-3.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ахтубинская СЭС 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Усть-Коксинская СЭС 3 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Усть-Коксинская СЭС 2 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Кош-Агачская 2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Песчаная СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар -БугульчанскаяСЭС1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Грачевка.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Нововаршавская СЭС 2 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Астерион.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Старомарьевская СЭС 3.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Нива.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Старомарьевская СЭС 6 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ахтубинская СЭС 1 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Григорьевская солнечная электр.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар -БугульчанскаяСЭС2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Новопереволоцкая СЭС 15 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Малодербетовская СЭС 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Усть-Коксинская СЭС 4 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Чемальская СЭС 10 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар -БугульчанскаяСЭС3.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Домбаровская СЭС 25 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Яшкульская 585 МВт 2 этап.xlsx
# Пропущен (нет погодных данных): ВИРЕО ЭНЕРДЖИ - Новый Свет-Эко.csv
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Торейская СЭС 45 МВт 2 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Элиста Северная.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Елшанская СЭС 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Лиманская СЭС 30 МВт 2 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Соль-Илецкая.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Кош-Агачская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Светлинская СЭС ПК-2 25 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ахтубинская СЭС 4 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Яшкульская СЭС 585 МВт-3.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Адыгейская ВЭС 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Усть-Канская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Майминская 2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Старомарьевская 5 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Усть-Коксинская СЭС 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Малодербетовская СЭС 60 МВт-2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Орловгайская 1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ахтубинская СЭС 3 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Новоузенская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Майминская 1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Красная.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Читинская СЭС 35 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Волгоградская СЭС 1 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Володаровка.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Грачевская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Сигма Дракона.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Хоринская СЭС 15 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Светлинская СЭС ПК-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Октябрьская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Плешановская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Сан проджект - Заводская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Онгудайская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Бичурская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Тарбагатай.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Лиманская СЭС 30 МВт 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/ЭкоСельЭнерго-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ининская 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Ташла.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Енотаевка.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Кабанская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/АвеларСолар - Исянгуловская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Майминская СЭС-3.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Нефтезаводская СЭС 20 МВт.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Адыгейская ВЭС 2 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Михайловская.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/ЭкоСельЭнерго-2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Фунтовская СЭС 4.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Яшкульская 585 МВт 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Бурибаевская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Лукойл - Волгоградская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Торейская СЭС 45 МВт 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Самарская СЭС-2 1 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Калмыкская СЭС-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Ининская СЭС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Фунтовская СЭС 1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Солнеч ветер Оренбургская СЭС-5.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Русско-Полянская СЭС 30 МВт-2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Самарская СЭС  2 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС БВС.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Промстройматериалы.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Луч 1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС Калиновка.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Фунтовская СЭС 2.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Нововаршавская СЭС 1 этап.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Русско-Полянская СЭС 30 МВт-1.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Орловгайская СЭС 2 очередь.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/СЭС им АА Влазнева.xlsx
# Округлено и сохранено в Excel: output/готовая_выработка_excel/Фунтовская СЭС 3.xlsx
